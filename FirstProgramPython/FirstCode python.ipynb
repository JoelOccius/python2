# %%
# store_revenu_1 = 1000
# store_revenu_2 = 1000

# if store_revenu_1 == store_revenu_2:
    # print("The store are equals")
# else:
    # print("The store are differente")

email_user = input("enter your email")
if not "@" in email_user:
     print("email invalid")
else:
     pass


# If age is less than 12 years old,
#  the price is $5. If age is less than
#  or equal to 12 and less than or
#  equal to 18, the price is $15.
#  If age is less than or equal to 18
#  or age less than or equal to 60,
#  the price is $36. Otherwise age is $10.

# Ask age user?

# age = int(input("enter your age:"))
# determine the ticket price
# if age < 12:
    # price = 5
# elif 12 <= age < 18:
    # price = 15
# elif 18 <= age < 60:
    # price = 36
# else:
    # price = 10

# show ticket price
# print(f"price ticket is ${price}.")


#Exercice1:Parity of a number,Write a program that asks the user to enter an integer.
#If the number is even, display the number is even.
#If not,display the number is odd.
#for example:4 is an even number.

#Asks user enter an integer number.
# number = int(input("enter your number:"))

#Check if the number is odd or even:
# if number % 2 == 0:
    # print("The number is odd:")
# else:
    # print("The number is even")


# Exercices 2: Compare two number and write
#  a program asking at the user enter two number .
# Show which one is than more or if both are equal.
# Exemple:
# Number1:10
# Number2:20 Exit
# The second number is than more

# Asks at the user enter two number 

# number1 = float(input("enter your first number:"))
# number2 = float(input("enter your second numbers:"))

# Compare numbers:
# if number1 > number2:
    # print("The first number is smaller.")
# elif number1 < number2:
    # print("The second number bigger.")
# else:
    # print("The two numbers are equal.")

# Exercice3:Categrisatin age:
# Write a program that asks the user her
#  age and who determine its category.

# determine its category.
# age = int(input("enter your age."))
# if age < 3:
    # print("The category is a Baby")
# elif  4 <= age < 11:
    # print("The categogy is teenage children.")
# elif 12 <= age < 17 :
    # print("The category is minor")
# elif 18 <= age < 59:
    # print("The category is Adult")
# else:
    # print("The category Old.")

# Exercice01:Rating grade.
# Write the program asks the  who user enter a grade on 20
# If the grade is is less than 10
# display insufficient.
# If the grade is between 10 and 14 (exclusive) display "Passable".
# If the grade is between 14 and 18 (exclusive) display "Good".
# If the grade is 18 or more display "Excelent".
# For exemple:Exit 16"Good" 

# Raiting the grade user:
# grade = float(input("Enter the grade:"))
# if grade < 10:
    # print(" Insufficient.")
# elif 10 < grade < 14:
    # print("Passable")
# elif 14 < grade < 18:
    # print("Good")
# else:
    # print("Excelent")

# Exercice02:
# Game of positive and negative numbers.
# Asks at a user enter a number.
# If the number is positive display "the number is positive",
# if the number is negative display "the number is negative",
# if the number is 0 display "the number is nul"
# Exemple:ented:-5 Exit "the number is Negative"

number = float(input("enter your number:"))
if number > 0:
    print("The number is positive")
elif number == 0:
    print("The number is nul")
else:
    print("The number is negative")
# Out:
# The number is nul
