# %%
# objective = 33
# quantity = 100

# if quantity > objective:
    # print(f"we realize our target{quantity}")
# else: 
    # print(f"we not realize our target{objective}")

# email = "occiusjoel@gmail.com"
# name = "Joel"

# print(email[2:])
# print(email[:4])
# print(name[1:])


# email = "occiusjoel@gmail.com"
# Email = "occiusjoel65@gmail.com"

# print("Work the e-mail " + str(len(email)) + " caracter")
# print(len(Email))
# print("Fisrt caracter " + email[0])
# print("last caracter " + email[-1])
# print("Mail server " + email[5:10])
# miness one

# Income = 10000
# Spent = 800
# Benefit = Income - Spent
# Adress = 42
# Superviser = 60

# print("The Income of store is "+ str(Benefit))
# print(f"The Income of store is {Benefit}")
# print("The Income of store is {}".format(Benefit))
# print("The Income of store is " , Benefit)
# print("The Income of store is {} and the spent is {}" .format(Income , Spent))
# print("The Income of the store is : %d and the spent is %d " %(Income , Spent))
# print("The Adress is: %d and Superviser is: %d and the spent is:  %s" % (Adress , Spent, Superviser))

# print("@" in "occiusjoel@gmail.com")
# print("@" in "occiusjoelgmail.com")

# Capitalize=> Makes all letters uppercase.(There is ... () but ... is usually better)
# text = ("joel")
# print(text.capitalize())
# casefold => Makes all letters lowercase.(There is lower () but casefold is usually better)
# message = ("Joel")
# print(message.casefold())

# count()=> number of times a value appears in the string
# text = ("occiusjoe@gmail.com")
# print(text.count("o"))

# endswith()=> ((Check if the text end by a value))
# checks if the text ends with a specific value and returns true or false
# 
# text = ("occiusjoe@gmail.com")
# print(text.endswith(".com")) 

# Find()=> finds the position of a value.
# (searches for a text in another text and reviews
#  the position of the text found in response...)
# text = ("occiusjoe@gmail.com")
# print(text.find("@")) 

# format()=>Formats a string based on the passed values.
#  We've used this a lot throughout the program.
# Income = 10000
# print("The income of store is ${} " .format(Income))

# isalnum()=>check if a text is entirely composed of alphanumeric characters (letters, numbers)
#  => those with accents or (ç) are considered as letters by this function.
# text = "joão123"
# print(text.isalnum()) 

# isalpha=>()Checks if a text is entirely(whole)(is) composed of letters
# text = "joão"
# print(text.isalpha())

# replace()=>Replaces text with another text in a string
# text = "2000.00"
# print(text.replace("2" , "JOEL"))

# split()=>Split a string according to a delimiter into several different texts.
# text = "joel occius"
# print(text.split(" "))

# splitlines()=>Split a text into several according to the text entries.
text = '''Good afternoon
       I am sending this email to inform you about today's store revenue.
       revenu = $3000
       '''
print(text.splitlines())

# startswich()=>Checks if the string starts with a certain text.
text = "BOBjoelJACQUELINE"
print(text.startswith("BOB"))

# strip()=>Remove unwanted characters from texts. By default, removes spaces, at the beginning or end.
text = "JOEL"
print(text.strip())

# title()=>capitalize the first letter of each word.
text = "joel occius"
print(text.title())

# upper()=>capitalize all letter 
text = "joel occius"
print(text.upper())

tag = (input("enter your CPF"))
    # Fòse yon tag vin gen 11 chif (pa egzanp, padonnen ak zewo)
if len(tag) <= 11 and tag.isdigit():
        print (tag.zfill(11))  # Ajoute zewo nan kòmansman pou rive 11 chif
else:
        print("Se pa li")
# Out:
# ['Good afternoon', "       I am sending this email to inform you about today's store revenue.", '       revenu = $3000', '       ']
# True
# JOEL
# Joel Occius
# JOEL OCCIUS
# 00000012345
